# %%
first_name = input( "Enter your first name: ")
last_name = input( "Enter your last name: ")
FellowID = input( "Enter your FellowID: ")
course = input( "Enter your course: ")
# Out:
# Enter your first name:  ABDUL
# Enter your last name:  MATEEN
# Enter your FellowID:  23/2292024DAV
# Enter your course:  DATA ANALYSIS

# %%
email = first_name.lower() + last_name.lower() + "@3mtt.mail"

# %%
welcome_message = f"""
=================================
WELCOME TO OMNI DIGITAL MEDIA INSTITUTE
=================================

Hello {first_name} {last_name},

We are excited to have you join us.

Your student details have been recorded successfully.
"""

print(welcome_message)
# Out:
# =================================
# WELCOME TO OMNI DIGITAL MEDIA INSTITUTE
# =================================
#
# Hello ABDUL MATEEN,
#
# We are excited to have you join us.
#
# Your student details have been recorded successfully.

# %%
print("STUDENT INFORMATION")
print("-------------------")
print(f"First Name: {first_name}")
print(f"Last Name: {last_name}")
print(f"FellowID: {FellowID}")
print(f"Course: {course}")
print(f"Email Address: {email}")
# Out:
# STUDENT INFORMATION
# -------------------
# First Name: ABDUL
# Last Name: MATEEN
# FellowID: 23/2292024DAV
# Course: DATA ANALYSIS
# Email Address: abdulmateen@3mtt.mail
